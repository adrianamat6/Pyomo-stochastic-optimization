# %%
# Import
from pyomo.environ import *

# Creation of a Concrete Model
model = ConcreteModel()

# Sets
model.i = Set(initialize=['gen1','gen2', 'gen3','gen4'], doc='generadores')
model.j = Set(initialize=['per1','per2','per3'], doc='periodos')
model.s = Set(initialize=['s1','s2','s3'], doc='escenarios de demanda')


# Parameters
model.F = Param(model.i, initialize = {'gen1':10, 'gen2':7, 'gen3':16, 'gen4':6}, doc = 'coste fijo de inversion')
model.PROBS = Param(model.s, initialize={'s1':0.333333,'s2':0.333333,'s3':0.333334}, doc='probabilidad de cada escenario [p.u.]')


# Tables
table1 = {
    ('gen1',  'per1') : 40,
    ('gen1',  'per2') : 24,
    ('gen1',  'per3') :  4,
    ('gen2',  'per1') : 45,
    ('gen2',  'per2') : 27,
    ('gen2',  'per3') : 2.5,
    ('gen3',  'per1') : 32,
    ('gen3',  'per2') : 19.2,
    ('gen3',  'per3') : 3.2,
    ('gen4',  'per1') : 55,
    ('gen4',  'per2') : 33,
    ('gen4',  'per3') : 5.5,
}


model.V = Param(model.i, model.j, initialize=table1, doc ='coste variable de operación [€ por MW]')


table2 = {
    ('s1','per1') : 3,
    ('s1','per2') : 3,
    ('s1','per3') : 2,
    ('s2','per1') : 5,
    ('s2','per2') : 3,
    ('s2','per3') : 2,
    ('s3','per1') : 7,
    ('s3','per2') : 3,
    ('s3','per3') : 2,
}


model.DEMS = Param(model.s, model.j, initialize=table2, doc ='demanda estocástica [MW]')


def dem_c(model,j):
    return sum(model.DEMS[s,j] * model.PROBS[s] for s in model.s) 
model.DEM = Param(model.j, initialize=dem_c, doc='demanda para un escenario [MW]')



# Scalar
model.POTMIN = Param(initialize=12, doc='potencia mínima a instalar [MW]')
model.PRSPTO = Param(initialize=120, doc='límite presupuestario [€]')


# Variables
model.X = Var(model.i, bounds=(0.0,None), doc='potencia a instalar [MW]')
model.Ys = Var(model.j, model.i, model.s,  bounds=(0.0,None), doc='potencia en operación [MW]')

# Equations
def coste_rule(model):
    return  sum(model.F[i] * model.X[i]  for i in model.i) + sum(model.V[i,j] * model.Y[j,i] for i in model.i for j in model.j)
model.coste = Objective(rule=coste_rule, sense=minimize, doc='coste total [€]')


def  presup_rule(model):
    return sum(model.F[i] * model.X[i] for i in model.i ) == model.PRSPTO
model.presup = Constraint(rule=presup_rule, doc='limitación presupuestaria [€]')


def  insmin_rule(model):
    return sum(model.X[i] for i in model.i ) >= model.POTMIN
model.insmin = Constraint(rule=insmin_rule, doc='potencia mínima instalada [MW]')


def  balpots_rule(model,s,j,i):
    return model.Ys[j,i,s] <= model.X[i]
model.balpot = Constraint(model.s, model.j, model.i, rule=balpots_rule, doc='potencia en operación menor que instalada [MW]')


#BALDEM(j) .. sum(i, Y(j,i)) =G= DEM(j)

def  baldems_rule(model,j,s):
    return sum(model.Ys[j,i,s] for i in model.i) >= model.DEMS[j,s] ; 
model.baldem = Constraint(model.j, rule=baldems_rule, doc='balance de demanda [MW]')


# SOLVE 
from pyomo.opt import SolverFactory
import pyomo.environ
opt = SolverFactory("glpk")
results = opt.solve(model)
 #sends results to stdout
results.write()

# display solution
model.display()
# Out:
# ERROR: Rule failed when generating expression for objective coste:
# 	AttributeError: 'ConcreteModel' object has no attribute 'Y'
# ERROR: Constructing component 'coste' from data=None failed:
# 	AttributeError: 'ConcreteModel' object has no attribute 'Y'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-34b11bdc96e0> in <module>()
#      70 def coste_rule(model):
#      71     return  sum(model.F[i] * model.X[i]  for i in model.i) + sum(model.V[i,j] * model.Y[j,i] for i in model.i for j in model.j)
# ---> 72 model.coste = Objective(rule=coste_rule, sense=minimize, doc='coste total [€]')
#      73
#      74
#
# ~\Anaconda3\lib\site-packages\pyomo\core\base\block.py in __setattr__(self, name, val)
#     540                 # Pyomo components are added with the add_component method.
#     541                 #
# --> 542                 self.add_component(name, val)
#     543             else:
#     544                 #
#
# ~\Anaconda3\lib\site-packages\pyomo\core\base\block.py in add_component(self, name, val)
#     967                               _blockName, str(data) )
#     968             try:
# --> 969                 val.construct(data)
#     970             except:
#     971                 err = sys.exc_info()[1]
#
# ~\Anaconda3\lib\site-packages\pyomo\core\base\objective.py in construct(self, data)
#     306             else:
#     307                 try:
# --> 308                     tmp = _init_rule(_self_parent)
#     309                 except Exception:
#     310                     err = sys.exc_info()[1]
#
# <ipython-input-1-34b11bdc96e0> in coste_rule(model)
#      69 # Equations
#      70 def coste_rule(model):
# ---> 71     return  sum(model.F[i] * model.X[i]  for i in model.i) + sum(model.V[i,j] * model.Y[j,i] for i in model.i for j in model.j)
#      72 model.coste = Objective(rule=coste_rule, sense=minimize, doc='coste total [€]')
#      73
#
# <ipython-input-1-34b11bdc96e0> in <genexpr>(.0)
#      69 # Equations
#      70 def coste_rule(model):
# ---> 71     return  sum(model.F[i] * model.X[i]  for i in model.i) + sum(model.V[i,j] * model.Y[j,i] for i in model.i for j in model.j)
#      72 model.coste = Objective(rule=coste_rule, sense=minimize, doc='coste total [€]')
#      73
#
# ~\Anaconda3\lib\site-packages\pyomo\core\base\block.py in __getattr__(self, val)
#     521         # throw the "normal" AttributeError
#     522         raise AttributeError("'%s' object has no attribute '%s'"
# --> 523                              % (self.__class__.__name__, val))
#     524
#     525     def __setattr__(self, name, val):
#
# AttributeError: 'ConcreteModel' object has no attribute 'Y'
